# %%
from src.notebook_helpers import detect_vulns, pretty_print

# %% [markdown]
# # Demo

# %%
detector_response = detect_vulns(chain="optimism", address="0xD9B45e2c389b6Ad55dD3631AbC1de6F2D2229847")
pretty_print(detector_response)
# Out:
# WARNING:CryticCompile:Warning: Warning: Unused local variable.
#   --> contracts/MoonHacker.sol:82:10:
#    |
# 82 |         (uint err, uint amountToReedem, uint amountToRepay, uint exRateMantissa) = IMToken(mToken).getAccountSnapshot(address(this));
#    |          ^^^^^^^^
#
#
# ...
#   --> contracts/MoonHacker.sol:82:61:
#    |
# 82 |         (uint err, uint amountToReedem, uint amountToRepay, uint exRateMantissa) = IMToken(mToken).getAccountSnapshot(address(this));
#    |                                                             ^^^^^^^^^^^^^^^^^^^
#
#
# ...
#    --> contracts/MoonHacker.sol:110:9:
#     |
# 110 |         address initiator,
#     |         ^^^^^^^^^^^^^^^^^
# MoonHacker.smartSupply(address,address,uint256,uint256)
# tainted_vars :  []
# tainted and input vars_to_check :  []
# vars_to_check(MoonHacker.smartSupply(address,address,uint256,uint256)) : ['token', 'mToken', 'amountToBorrow', 'amountToSupply']
#
# MoonHacker.smartRedeem(address,address)
# ...

# %%
# Li.Fi Hack
detector_response = detect_vulns(chain="ethereum", address="0xf28A352377663cA134bd27B582b1a9A4dad7e534")
pretty_print(detector_response)
# Out:
# tainted_vars :  []
# tainted and input vars_to_check :  []
# vars_to_check(GasZipFacet.startBridgeTokensViaGasZip(ILiFi.BridgeData,GasZipFacet.GasZipData)) : ['_bridgeData', '_gasZipData']
# tainted_vars :  []
# tainted and input vars_to_check :  []
#
# tainted_vars :  []
# tainted and input vars_to_check :  []
# vars_to_check(GasZipFacet.swapAndStartBridgeTokensViaGasZip(ILiFi.BridgeData,LibSwap.SwapData[],GasZipFacet.GasZipData)) : ['_bridgeData', '_swapData', '_gasZipData']
# tainted_vars :  []
# tainted and input vars_to_check :  []
# tainted_vars :  []
# tainted and input vars_to_check :  []
#
# tainted_vars :  []
# tainted and input vars_to_check :  []
# vars_to_check(GasZipFacet.depositToGasZipERC20(LibSwap.SwapData,uint256,address)) : ['_swapData', '_destinationChains', '_recipient']
# tainted_vars :  ['success', 'res', 'success', 'res']
# tainted and input vars_to_check :  ['_swap']
# ❌ unvalidated tainted/inp var in calls : _swap
# ...

# %%
# Arcadia Finance
detector_response = detect_vulns(chain="base", address="0xC729213B9b72694F202FeB9cf40FE8ba5F5A4509")
pretty_print(detector_response)
# Out:
# ERROR:ContractSolcParsing:Impossible to generate IR for SlipstreamLogic._computePoolAddress (src/rebalancers/libraries/SlipstreamLogic.sol#30-36):
#  'NoneType' object has no attribute 'parameters'
# tainted_vars :  []
# tainted and input vars_to_check :  []
# vars_to_check(ERC20.permit(address,address,uint256,uint256,uint8,bytes32,bytes32)) : ['owner', 'spender', 'value', 'deadline', 'v', 'r', 's']
#
# tainted_vars :  []
# tainted and input vars_to_check :  ['account_']
# vars_to_check(Rebalancer.rebalance(address,address,uint256,int24,int24,bytes)) : ['account_', 'positionManager', 'oldId', 'tickLower', 'tickUpper', 'swapData']
# tainted_vars :  []
# tainted and input vars_to_check :  []
#
# ...

# %%
#SuperRare Hack
detector_response = detect_vulns(chain="ethereum", address="0xfFB512B9176D527C5D32189c3e310Ed4aB2Bb9eC")
pretty_print(detector_response)
# Out:
# tainted_vars :  []
# tainted and input vars_to_check :  []
# vars_to_check(RareStakingV1.stake(uint256)) : ['amount']
# tainted_vars :  []
# tainted and input vars_to_check :  []
#
# tainted_vars :  []
# tainted and input vars_to_check :  []
# vars_to_check(RareStakingV1.unstake(uint256)) : ['amount']
# tainted_vars :  []
# tainted and input vars_to_check :  []
#
# tainted_vars :  []
# tainted and input vars_to_check :  []
# vars_to_check(RareStakingV1.claim(uint256,bytes32[])) : ['amount', 'proof']
# tainted_vars :  []
# tainted and input vars_to_check :  []
# tainted_vars :  []
# tainted and input vars_to_check :  []
# tainted_vars :  []
# tainted and input vars_to_check :  []
# tainted_vars :  []
# tainted and input vars_to_check :  []
#
# tainted_vars :  []
# tainted and input vars_to_check :  []
# vars_to_check(RareStakingV1.upgradeTo(address)) : ['newImplementation']
# tainted_vars :  []
# tainted and input vars_to_check :  []
# tainted_vars :  []
# ...

# %%
#MoonHacker Hack
detector_response = detect_vulns(chain="optimism", address="0xD9B45e2c389b6Ad55dD3631AbC1de6F2D2229847")
pretty_print(detector_response)
# Out:
# WARNING:CryticCompile:Warning: Warning: Unused local variable.
#   --> contracts/MoonHacker.sol:82:10:
#    |
# 82 |         (uint err, uint amountToReedem, uint amountToRepay, uint exRateMantissa) = IMToken(mToken).getAccountSnapshot(address(this));
#    |          ^^^^^^^^
#
#
# ...
#   --> contracts/MoonHacker.sol:82:61:
#    |
# 82 |         (uint err, uint amountToReedem, uint amountToRepay, uint exRateMantissa) = IMToken(mToken).getAccountSnapshot(address(this));
#    |                                                             ^^^^^^^^^^^^^^^^^^^
#
#
# ...
#    --> contracts/MoonHacker.sol:110:9:
#     |
# 110 |         address initiator,
#     |         ^^^^^^^^^^^^^^^^^
# tainted_vars :  []
# tainted and input vars_to_check :  []
# vars_to_check(MoonHacker.smartSupply(address,address,uint256,uint256)) : ['token', 'mToken', 'amountToBorrow', 'amountToSupply']
#
# ...

# %%
#Silo Hack
detector_response = detect_vulns(chain="ethereum", address="0xCbEe4617ABF667830fe3ee7DC8d6f46380829DF9")
pretty_print(detector_response)
# Out:
# tainted_vars :  []
# tainted and input vars_to_check :  ['_depositArgs']
# ❌ unvalidated tainted/inp var in calls : _depositArgs
# ✨RESULT:  {'LeverageUsingSiloFlashloan.openLeveragePositionPermit(ILeverageUsingSiloFlashloan.FlashArgs,bytes,ILeverageUsingSiloFlashloan.DepositArgs,ILeverageUsingSiloFlashloan.Permit)': [('LeverageUsingSiloFlashloan.openLeveragePositionPermit(ILeverageUsingSiloFlashloan.FlashArgs,bytes,ILeverageUsingSiloFlashloan.DepositArgs,ILeverageUsingSiloFlashloan.Permit)._depositArgs', ['_depositArgs.silo.asset()'])]}
# vars_to_check(LeverageUsingSiloFlashloan.openLeveragePositionPermit(ILeverageUsingSiloFlashloan.FlashArgs,bytes,ILeverageUsingSiloFlashloan.DepositArgs,ILeverageUsingSiloFlashloan.Permit)) : ['_flashArgs', '_swapArgs', '_depositArgs', '_depositAllowance']
# tainted_vars :  []
# tainted and input vars_to_check :  []
# tainted_vars :  []
# tainted and input vars_to_check :  ['_flashArgs']
# ❌ unvalidated tainted/inp var in calls : _flashArgs
# ...

# %%
#MetaPool Hack
detector_response = detect_vulns(chain="ethereum", address="0x3747484567119592fF6841df399cf679955A111A")
pretty_print(detector_response)
# Out:
# WARNING:CryticCompile:Warning: Warning: Unnamed return variable can remain unassigned. Add an explicit return with value to all non-reverting code paths or name the variable.
#    --> @openzeppelin/contracts-upgradeable/utils/AddressUpgradeable.sol:175:30:
#     |
# 175 |     ) internal view returns (bytes memory) {
#     |                              ^^^^^^^^^^^^
#
#
# ...
#    --> @openzeppelin/contracts-upgradeable/utils/AddressUpgradeable.sol:198:30:
#     |
# 198 |     ) internal pure returns (bytes memory) {
#     |                              ^^^^^^^^^^^^
# tainted_vars :  []
# tainted and input vars_to_check :  ['_weth']
# ❌ unvalidated tainted/inp var in calls : _weth
# ✨RESULT:  {'LiquidUnstakePool.initialize(address,IERC20MetadataUpgradeable,address)': [('LiquidUnstakePool.initialize(address,IERC20MetadataUpgradeable,address)._weth', ['_weth.decimals()'])]}
# ...
